# %%
# Check path existence
import os

print("="*60)
print("CHECKING FILE STRUCTURE")
print("="*60)

paths = [
    '/content/model/data.yaml',
    '/content/model/train_yolov8.py',
    '/content/new_train_test_data/train/images',
    '/content/new_train_test_data/train/labels',
    '/content/new_train_test_data/val/images',
    '/content/new_train_test_data/val/labels',
    '/content/new_train_test_data/test'
]

for path in paths:
    if os.path.isfile(path):
        print(f"✓ File: {path}")
    elif os.path.isdir(path):
        count = len(os.listdir(path))
        print(f"✓ Directory: {path} ({count} files)")
    else:
        print(f"✗ NOT FOUND: {path}")

print("="*60)
# Out:
# ...
# CHECKING FILE STRUCTURE
# ...
# ✓ File: /content/model/data.yaml
# ✓ File: /content/model/train_yolov8.py
# ✓ Directory: /content/new_train_test_data/train/images (1232 files)
# ✓ Directory: /content/new_train_test_data/train/labels (1232 files)
# ✓ Directory: /content/new_train_test_data/val/images (153 files)
# ✓ Directory: /content/new_train_test_data/val/labels (153 files)
# ✓ Directory: /content/new_train_test_data/test (153 files)
# ...

# %%
# Check GPU
import torch

print("="*60)
print("GPU CHECK")
print("="*60)
print(f"✓ CUDA available: {torch.cuda.is_available()}")
print(f"✓ GPU: {torch.cuda.get_device_name(0)}")
print(f"✓ GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
print("="*60)
# Out:
# ...
# GPU CHECK
# ...
# ✓ CUDA available: True
# ✓ GPU: Tesla T4
# ✓ GPU Memory: 14.74 GB
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.8 MB/s eta 0:00:00
# ...

# %%
# !python /content/model/train_yolov8.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
